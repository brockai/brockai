# %%
from dotenv import load_dotenv
from opensearchpy import OpenSearch
import airflow_client.client
import os

load_dotenv()

opensearch_host = os.getenv("OPENSEARCH_HOST")
opensearch_host_port = os.getenv("OPENSEARCH_HOST_PORT")
opensearch_platform = os.getenv("OPENSEARCH_PLATFORM")
opensearch_user = os.getenv("OPENSEARCH_USER")
opensearch_password = os.getenv("OPENSEARCH_PASSWORD")
airflow_api = os.getenv("AIRFLOW_API")
airflow_api_user = os.getenv("AIRFLOW_API_USER")
airflow_api_password = os.getenv("AIRFLOW_API_PASSWORD")

auth = (opensearch_user, opensearch_password)

client = OpenSearch(
    hosts = [{'host':  opensearch_host, 'port': opensearch_host_port}],
    http_compress = True,
    ssl_show_warn = False,
    http_auth = auth,
    use_ssl = True,
    verify_certs = False
)

airflow_configuration = airflow_client.client.Configuration(
    host=airflow_api,
    username=airflow_api_user,
    password=airflow_api_password
)

# %%
#opensearch health
def check_opensearch_health():
    try:
        info = client.info()
        return info
           
    except Exception as e:
        error_message = str(e)
        return error_message

health = check_opensearch_health()

print(health)

#airflow health
from airflow_client.client.api import config_api, dag_api, dag_run_api, connection_api, monitoring_api
from airflow_client.client.model.dag_run import DAGRun

api_client = airflow_client.client.ApiClient(airflow_configuration)
connection_client = connection_api.ConnectionApi(api_client)
monitoring_client = monitoring_api.MonitoringApi(api_client)

def get_connection_health(): 

    try:
        response = connection_client.get_connections()
        return response
    
    except airflow_client.client.OpenApiException as e:
        error_message = str(e)
        return error_message

def get_database_scheduler_health(): 

    try:
        response = monitoring_client.get_health()
        return response
    
    except airflow_client.client.OpenApiException as e:
        error_message = str(e)
        return error_message

health_connections = get_connection_health()
health_database_scheduler = get_database_scheduler_health()

print(health_connections)
print(health_database_scheduler)
# Out:
# {'name': 'opensearch-node1', 'cluster_name': 'opensearch-cluster', 'cluster_uuid': 'LLIZ0KaiQy65zfPwAAUmWg', 'version': {'distribution': 'opensearch', 'number': '2.11.1', 'build_type': 'tar', 'build_hash': '6b1986e964d440be9137eba1413015c31c5a7752', 'build_date': '2023-11-29T21:43:10.135035992Z', 'build_snapshot': False, 'lucene_version': '9.7.0', 'minimum_wire_compatibility_version': '7.10.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'The OpenSearch Project: https://opensearch.org/'}
# {'connections': [{'conn_type': 'mysql',
#                   'connection_id': 'airflow_db',
#                   'description': None,
#                   'host': 'mysql',
#                   'login': 'root',
#                   'port': None,
#                   'schema': 'airflow'},
#                  {'conn_type': 'aws',
#                   'connection_id': 'aws_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'azure_batch',
#                   'connection_id': 'azure_batch_default',
#                   'description': None,
#                   'host': None,
#                   'login': '<ACCOUNT_NAME>',
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'azure_cosmos',
#                   'connection_id': 'azure_cosmos_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'azure_data_explorer',
#                   'connection_id': 'azure_data_explorer_default',
#                   'description': None,
#                   'host': 'https://<CLUSTER>.kusto.windows.net',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'azure_data_lake',
#                   'connection_id': 'azure_data_lake_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'azure',
#                   'connection_id': 'azure_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'cassandra',
#                   'connection_id': 'cassandra_default',
#                   'description': None,
#                   'host': 'cassandra',
#                   'login': None,
#                   'port': 9042,
#                   'schema': None},
#                  {'conn_type': 'databricks',
#                   'connection_id': 'databricks_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'http',
#                   'connection_id': 'dingding_default',
#                   'description': None,
#                   'host': '',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'drill',
#                   'connection_id': 'drill_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 8047,
#                   'schema': None},
#                  {'conn_type': 'druid',
#                   'connection_id': 'druid_broker_default',
#                   'description': None,
#                   'host': 'druid-broker',
#                   'login': None,
#                   'port': 8082,
#                   'schema': None},
#                  {'conn_type': 'druid',
#                   'connection_id': 'druid_ingest_default',
#                   'description': None,
#                   'host': 'druid-overlord',
#                   'login': None,
#                   'port': 8081,
#                   'schema': None},
#                  {'conn_type': 'elasticsearch',
#                   'connection_id': 'elasticsearch_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 9200,
#                   'schema': 'http'},
#                  {'conn_type': 'emr',
#                   'connection_id': 'emr_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'facebook_social',
#                   'connection_id': 'facebook_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'fs',
#                   'connection_id': 'fs_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'google_cloud_platform',
#                   'connection_id': 'google_cloud_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': 'default'},
#                  {'conn_type': 'hive_cli',
#                   'connection_id': 'hive_cli_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 10000,
#                   'schema': 'default'},
#                  {'conn_type': 'hiveserver2',
#                   'connection_id': 'hiveserver2_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 10000,
#                   'schema': 'default'},
#                  {'conn_type': 'http',
#                   'connection_id': 'http_default',
#                   'description': None,
#                   'host': 'https://www.httpbin.org/',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'kubernetes',
#                   'connection_id': 'kubernetes_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'kylin',
#                   'connection_id': 'kylin_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': 'ADMIN',
#                   'port': 7070,
#                   'schema': None},
#                  {'conn_type': 'leveldb',
#                   'connection_id': 'leveldb_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'livy',
#                   'connection_id': 'livy_default',
#                   'description': None,
#                   'host': 'livy',
#                   'login': None,
#                   'port': 8998,
#                   'schema': None},
#                  {'conn_type': 'mysql',
#                   'connection_id': 'local_mysql',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': 'airflow',
#                   'port': None,
#                   'schema': 'airflow'},
#                  {'conn_type': 'hive_metastore',
#                   'connection_id': 'metastore_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 9083,
#                   'schema': None},
#                  {'conn_type': 'mongo',
#                   'connection_id': 'mongo_default',
#                   'description': None,
#                   'host': 'mongo',
#                   'login': None,
#                   'port': 27017,
#                   'schema': None},
#                  {'conn_type': 'mssql',
#                   'connection_id': 'mssql_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 1433,
#                   'schema': None},
#                  {'conn_type': 'mysql',
#                   'connection_id': 'mysql_default',
#                   'description': None,
#                   'host': 'mysql',
#                   'login': 'root',
#                   'port': None,
#                   'schema': 'airflow'},
#                  {'conn_type': 'http',
#                   'connection_id': 'opsgenie_default',
#                   'description': None,
#                   'host': '',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'oss',
#                   'connection_id': 'oss_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'pig_cli',
#                   'connection_id': 'pig_cli_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': 'default'},
#                  {'conn_type': 'pinot',
#                   'connection_id': 'pinot_admin_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 9000,
#                   'schema': None},
#                  {'conn_type': 'pinot',
#                   'connection_id': 'pinot_broker_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 9000,
#                   'schema': None},
#                  {'conn_type': 'postgres',
#                   'connection_id': 'postgres_default',
#                   'description': None,
#                   'host': 'postgres',
#                   'login': 'postgres',
#                   'port': None,
#                   'schema': 'airflow'},
#                  {'conn_type': 'presto',
#                   'connection_id': 'presto_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 3400,
#                   'schema': 'hive'},
#                  {'conn_type': 'qubole',
#                   'connection_id': 'qubole_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'redis',
#                   'connection_id': 'redis_default',
#                   'description': None,
#                   'host': 'redis',
#                   'login': None,
#                   'port': 6379,
#                   'schema': None},
#                  {'conn_type': 'redshift',
#                   'connection_id': 'redshift_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'segment',
#                   'connection_id': 'segment_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'sftp',
#                   'connection_id': 'sftp_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': 'airflow',
#                   'port': 22,
#                   'schema': None},
#                  {'conn_type': 'spark',
#                   'connection_id': 'spark_default',
#                   'description': None,
#                   'host': 'yarn',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'sqlite',
#                   'connection_id': 'sqlite_default',
#                   'description': None,
#                   'host': '/tmp/sqlite_default.db',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'sqoop',
#                   'connection_id': 'sqoop_default',
#                   'description': None,
#                   'host': 'rdbms',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'ssh',
#                   'connection_id': 'ssh_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'tableau',
#                   'connection_id': 'tableau_default',
#                   'description': None,
#                   'host': 'https://tableau.server.url',
#                   'login': 'user',
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'trino',
#                   'connection_id': 'trino_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 3400,
#                   'schema': 'hive'},
#                  {'conn_type': 'vertica',
#                   'connection_id': 'vertica_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 5433,
#                   'schema': None},
#                  {'conn_type': 'wasb',
#                   'connection_id': 'wasb_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': None},
#                  {'conn_type': 'hdfs',
#                   'connection_id': 'webhdfs_default',
#                   'description': None,
#                   'host': 'localhost',
#                   'login': None,
#                   'port': 50070,
#                   'schema': None},
#                  {'conn_type': 'yandexcloud',
#                   'connection_id': 'yandexcloud_default',
#                   'description': None,
#                   'host': None,
#                   'login': None,
#                   'port': None,
#                   'schema': 'default'}],
#  'total_entries': 52.0}
# {'metadatabase': {'status': 'healthy'},
#  'scheduler': {'latest_scheduler_heartbeat': '2024-02-28T17:10:48.243356+00:00',
#                'status': 'healthy'}}

# %%
df.head()
# Out:
#   PrimaryID  Var  Rev                     Description     Policy  \
# 0    112996  NaN  NaN               14GA LGRN TXL (S)  EU RoHS 2
# 1    112995  NaN  NaN                14GA GRY TXL (S)  EU RoHS 2
# 2    109961  NaN  NaN                16GA YEL TXL (S)  EU RoHS 2
# 3    108652  NaN  NaN                18GA GRY TXL (S)  EU RoHS 2
# 4    124901  NaN  NaN  93-144820-16S   16 WAY MS PLUG  EU RoHS 2
#
#       PolicyVersion                   Judgement       Declarables  \
# 0  EUROHS-1907 (10)             under-threshold               NaN
# 1  EUROHS-1907 (10)             under-threshold               NaN
# 2  EUROHS-1907 (10)             under-threshold               NaN
# 3  EUROHS-1907 (10)             under-threshold               NaN
# 4  EUROHS-1907 (10)  above-threshold-exemptions  ECHA Name : Lead
#
#                Suppliers    Status   Manufacturers Customers  \
# 0  THERM-O-LINK COMPANY   complete       TXL WIRE        NaN
# 1  THERM-O-LINK COMPANY   complete       TXL WIRE        NaN
# 2  THERM-O-LINK COMPANY   complete       TXL WIRE        NaN
# 3  THERM-O-LINK COMPANY   complete       TXL WIRE        NaN
# 4              TTI INC.   complete  AMPHENOL CORP        NaN
#
#                       OtherIDs  HasBom
# 0      14GA_x000D_,14GA_x000D_   False
# 1      14GA_x000D_,14GA_x000D_   False
# 2      16GA_x000D_,16GA_x000D_   False
# 3      18GA_x000D_,18GA_x000D_   False
# 4  93-144820-16S,93-144820-16S   False

# %%
df = df.drop('Var', axis=1)
df = df.drop('HasBom', axis=1)
df = df.drop('Status', axis=1)
# not enough data
df = df.drop('Customers', axis=1)
df = df.drop('Rev', axis=1)
df.head()
# Out:
#   PrimaryID                     Description     Policy     PolicyVersion  \
# 0    112996               14GA LGRN TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 1    112995                14GA GRY TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 2    109961                16GA YEL TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 3    108652                18GA GRY TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 4    124901  93-144820-16S   16 WAY MS PLUG  EU RoHS 2  EUROHS-1907 (10)
#
#                     Judgement       Declarables              Suppliers  \
# 0             under-threshold               NaN  THERM-O-LINK COMPANY
# 1             under-threshold               NaN  THERM-O-LINK COMPANY
# 2             under-threshold               NaN  THERM-O-LINK COMPANY
# 3             under-threshold               NaN  THERM-O-LINK COMPANY
# 4  above-threshold-exemptions  ECHA Name : Lead              TTI INC.
#
#     Manufacturers                     OtherIDs
# 0       TXL WIRE       14GA_x000D_,14GA_x000D_
# 1       TXL WIRE       14GA_x000D_,14GA_x000D_
# 2       TXL WIRE       16GA_x000D_,16GA_x000D_
# 3       TXL WIRE       18GA_x000D_,18GA_x000D_
# 4  AMPHENOL CORP   93-144820-16S,93-144820-16S

# %%
df.value_counts('PrimaryID')
# Out:
# PrimaryID
# 126676    41
# 105941    38
# 127721    37
# 107333    33
# 101666    32
#           ..
# 127971     1
# 127984     1
# 113132     1
# 150371     1
# 116493     1
# Name: count, Length: 7378, dtype: int64

# %%
df.value_counts('PrimaryID').value_counts()
# Out:
# count
# 1     1704
# 2     1340
# 4      915
# 3      881
# 5      437
# 6      386
# 8      310
# 7      285
# 9      196
# 10     152
# 11      97
# 13      72
# 14      71
# 12      70
# 15      64
# 16      58
# 18      50
# 17      37
# 25      36
# 23      33
# 19      30
# 20      30
# 21      28
# 24      28
# 22      22
# 26      14
# 27      11
# 28      10
# 29       3
# 32       3
# 33       1
# 37       1
# 38       1
# 30       1
# 41       1
# Name: count, dtype: int64

# %%
df = df.set_index('PrimaryID')
df.head()
# Out:
#                               Description     Policy     PolicyVersion  \
# PrimaryID
# 112996                  14GA LGRN TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 112995                   14GA GRY TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 109961                   16GA YEL TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 108652                   18GA GRY TXL (S)  EU RoHS 2  EUROHS-1907 (10)
# 124901     93-144820-16S   16 WAY MS PLUG  EU RoHS 2  EUROHS-1907 (10)
#
#                             Judgement       Declarables  \
# PrimaryID
# 112996                under-threshold               NaN
# 112995                under-threshold               NaN
# 109961                under-threshold               NaN
# 108652                under-threshold               NaN
# 124901     above-threshold-exemptions  ECHA Name : Lead
#
#                        Suppliers   Manufacturers                     OtherIDs
# PrimaryID
# 112996     THERM-O-LINK COMPANY        TXL WIRE       14GA_x000D_,14GA_x000D_
# 112995     THERM-O-LINK COMPANY        TXL WIRE       14GA_x000D_,14GA_x000D_
# 109961     THERM-O-LINK COMPANY        TXL WIRE       16GA_x000D_,16GA_x000D_
# 108652     THERM-O-LINK COMPANY        TXL WIRE       18GA_x000D_,18GA_x000D_
# 124901                 TTI INC.   AMPHENOL CORP   93-144820-16S,93-144820-16S

# %%
df.value_counts('Judgement')
# Out:
# Judgement
# under-threshold               30435
# not-applicable                 3053
# above-threshold                1148
# other                           786
# above-threshold-exemptions      375
# obsolete-item                   279
# unknown-item                      1
# Name: count, dtype: int64

# %%
df['Declarables'].count()
# Out:
# 1478

# %%
df['Declarables'].value_counts()
# Out:
# Declarables
# ECHA Name : Lead                                                                                                                                                                                                                                                                                                    1037
# ECHA Name : Lead and its compounds                                                                                                                                                                                                                                                                                   150
# ECHA Name : Nickel                                                                                                                                                                                                                                                                                                    26
# ECHA Name : Chromium (VI) Compounds                                                                                                                                                                                                                                                                                   23
# ECHA Name : Octamethylcyclotetrasiloxane                                                                                                                                                                                                                                                                              21
# ECHA Name : Cadmium                                                                                                                                                                                                                                                                                                   19
# ECHA Name : Diantimony trioxide                                                                                                                                                                                                                                                                                       17
# ECHA Name : 1,6,7,8,9,14,15,16,17,17,18,18-Dodecachloropentacyclo[12.2.1.16,9.02,13.05,10]octadeca-7,15-diene ("Dechlorane Plus"™)                                                                                                                                                                                    17
# ECHA Name : Lead and its compounds,ECHA Name : Cadmium oxide                                                                                                                                                                                                                                                          16
# ECHA Name : Cadmium/Cadmium compounds                                                                                                                                                                                                                                                                                 13
# ECHA Name : Cadmium/Cadmium compounds,ECHA Name : Lead and its compounds                                                                                                                                                                                                                                               9
# ECHA Name : Decamethylcyclopentasiloxane,ECHA Name : Lead                                                                                                                                                                                                                                                              9
# ECHA Name : 4-(1,1,3,3-tetramethylbutyl)phenol,ECHA Name : 2-ethylhexyl 10-ethyl-4,4-dioctyl-7-oxo-8-oxa-3,5-dithia-4-stannatetradecanoate                                                                                                                                                                             8
# ECHA Name : Bis(2-ethylhexyl) phthalate                                                                                                                                                                                                                                                                                6
# ECHA Name : Diantimony trioxide,ECHA Name : Carbon black                                                                                                                                                                                                                                                               6
# ECHA Name : Lead,ECHA Name : Cadmium oxide                                                                                                                                                                                                                                                                             6
# ECHA Name : Cadmium oxide,ECHA Name : Lead,ECHA Name : C,C'-azodi(formamide)                                                                                                                                                                                                                                           6
# ECHA Name : Lead,ECHA Name : Cadmium oxide,ECHA Name : C,C'-azodi(formamide)                                                                                                                                                                                                                                           5
# ECHA Name : Formaldehyde                                                                                                                                                                                                                                                                                               5
# ECHA Name : Cadmium,ECHA Name : Lead                                                                                                                                                                                                                                                                                   5
# ECHA Name : Lead,ECHA Name : C,C'-azodi(formamide)                                                                                                                                                                                                                                                                     4
# ECHA Name : Lead,ECHA Name : Decamethylcyclopentasiloxane                                                                                                                                                                                                                                                              4
# ECHA Name : 2-methyl-1-(4-methylthiophenyl)-2-morpholinopropan-1-one,ECHA Name : Lead                                                                                                                                                                                                                                  4
# ECHA Name : C,C'-azodi(formamide)                                                                                                                                                                                                                                                                                      1
# ECHA Name : Lead,ECHA Name : C,C'-azodi(formamide),ECHA Name : Cadmium oxide                                                                                                                                                                                                                                           1
# ECHA Name : Hexahydromethylphthalic anhydride                                                                                                                                                                                                                                                                          1
# ECHA Name : Ethylbenzene,ECHA Name : Cumene,ECHA Name : Styrene                                                                                                                                                                                                                                                        1
# ECHA Name : Arsenic,ECHA Name : Beryllium,ECHA Name : Cadmium,ECHA Name : Cobalt,ECHA Name : Lead,ECHA Name : Mercury,ECHA Name : Nickel                                                                                                                                                                               1
# ECHA Name : Octamethylcyclotetrasiloxane,Other : Other Chlorinated Flame Retardants                                                                                                                                                                                                                                    1
# ECHA Name : 2,4-di-tert-butyl-6-(5-chlorobenzotriazol-2-yl)phenol,ECHA Name : Tris(4-nonylphenyl, branched and linear) phosphite (TNPP) with ≥ 0.1% w/w of 4-nonylphenol, branched and linear (4-NP)                                                                                                                   1
# ECHA Name : 2,4-di-tert-butyl-6-(5-chlorobenzotriazol-2-yl)phenol                                                                                                                                                                                                                                                      1
# ECHA Name : Styrene,ECHA Name : Acrylonitrile                                                                                                                                                                                                                                                                          1
# ECHA Name : 2,4-di-tert-butyl-6-(5-chlorobenzotriazol-2-yl)phenol,ECHA Name : Tris(nonylphenyl) phosphite,ECHA Name : C,C'-azodi(formamide)                                                                                                                                                                            1
# ECHA Name : "silicon dioxide; synthetic amorphous silicon dioxide (nano)",ECHA Name : Nickel                                                                                                                                                                                                                           1
# ECHA Name : 2-(2H-benzotriazol-2-yl)-4,6-ditertpentylphenol,ECHA Name : Lead,ECHA Name : Bis(2-ethylhexyl) phthalate                                                                                                                                                                                                   1
# ECHA Name : Decamethylcyclopentasiloxane                                                                                                                                                                                                                                                                               1
# ECHA Name : Imidazolidine-2-thione                                                                                                                                                                                                                                                                                     1
# ECHA Name : Lead monoxide                                                                                                                                                                                                                                                                                              1
# Name: count, dtype: int64

# %%
def rowSplit(x):
    if isinstance(x, str):
        temp = x.split(',E')
        return temp
    else:
        return x

df['Declarables'] = df['Declarables'].apply(rowSplit)

# %%
df['Declarables'].value_counts()
# Out:
# [ECHA Name : Lead]                                                                                                                                                                                                                                                                                                    1037
# [ECHA Name : Lead and its compounds]                                                                                                                                                                                                                                                                                   150
# [ECHA Name : Nickel]                                                                                                                                                                                                                                                                                                    26
# [ECHA Name : Chromium (VI) Compounds]                                                                                                                                                                                                                                                                                   23
# [ECHA Name : Octamethylcyclotetrasiloxane]                                                                                                                                                                                                                                                                              21
# [ECHA Name : Cadmium]                                                                                                                                                                                                                                                                                                   19
# [ECHA Name : Diantimony trioxide]                                                                                                                                                                                                                                                                                       17
# [ECHA Name : 1,6,7,8,9,14,15,16,17,17,18,18-Dodecachloropentacyclo[12.2.1.16,9.02,13.05,10]octadeca-7,15-diene ("Dechlorane Plus"™)]                                                                                                                                                                                    17
# [ECHA Name : Lead and its compounds, CHA Name : Cadmium oxide]                                                                                                                                                                                                                                                          16
# [ECHA Name : Polyethylene glycol p-(1,1,3,3-tetramethylbutyl)phenyl ether]                                                                                                                                                                                                                                               2
# [ECHA Name : Cadmium/Cadmium compounds, CHA Name : Hexabromocyclododecane (HBCDD), CHA Name : Lead and its compounds]                                                                                                                                                                                                    2
# [ECHA Name : Cadmium oxide, CHA Name : Lead]                                                                                                                                                                                                                                                                             2
# [ECHA Name : Methanol, CHA Name : Toluene, CHA Name : Cadmium/Cadmium compounds, CHA Name : Formaldehyde, CHA Name : Lead and its compounds, CHA Name : Mercury and mercury compounds, CHA Name : Nickel and its compounds, CHA Name : Polychlorinated Biphenyls (PCB),Other : Other Chlorinated Flame Retardants]       1
# [ECHA Name : Nickel, CHA Name : Lead, CHA Name : Lead]                                                                                                                                                                                                                                                                   1
# [ECHA Name : Decamethylcyclopentasiloxane, CHA Name : Dodecamethylcyclohexasiloxane]                                                                                                                                                                                                                                     1
# [ECHA Name : Boric Acid]                                                                                                                                                                                                                                                                                                 1
# [ECHA Name : 2-chlorobuta-1,3-diene]                                                                                                                                                                                                                                                                                     1
# [ECHA Name : Benzyl butyl phthalate]                                                                                                                                                                                                                                                                                     1
# [ECHA Name : Cyclohexane-1,2-dicarboxylic anhydride]                                                                                                                                                                                                                                                                     1
# [ECHA Name : Dodecamethylcyclohexasiloxane]                                                                                                                                                                                                                                                                              1
# [ECHA Name : Diantimony trioxide, CHA Name : Carbon black, CHA Name : "silicon dioxide; synthetic amorphous silicon dioxide (nano)"]                                                                                                                                                                                     1
# [ECHA Name : C,C'-azodi(formamide)]                                                                                                                                                                                                                                                                                      1
# [ECHA Name : Lead, CHA Name : C,C'-azodi(formamide), CHA Name : Cadmium oxide]                                                                                                                                                                                                                                           1
# [ECHA Name : Hexahydromethylphthalic anhydride]                                                                                                                                                                                                                                                                          1
# [ECHA Name : Ethylbenzene, CHA Name : Cumene, CHA Name : Styrene]                                                                                                                                                                                                                                                        1
# [ECHA Name : Arsenic, CHA Name : Beryllium, CHA Name : Cadmium, CHA Name : Cobalt, CHA Name : Lead, CHA Name : Mercury, CHA Name : Nickel]                                                                                                                                                                               1
# [ECHA Name : Octamethylcyclotetrasiloxane,Other : Other Chlorinated Flame Retardants]                                                                                                                                                                                                                                    1
# [ECHA Name : 2,4-di-tert-butyl-6-(5-chlorobenzotriazol-2-yl)phenol, CHA Name : Tris(4-nonylphenyl, branched and linear) phosphite (TNPP) with ≥ 0.1% w/w of 4-nonylphenol, branched and linear (4-NP)]                                                                                                                   1
# [ECHA Name : 2,4-di-tert-butyl-6-(5-chlorobenzotriazol-2-yl)phenol]                                                                                                                                                                                                                                                      1
# [ECHA Name : Styrene, CHA Name : Acrylonitrile]                                                                                                                                                                                                                                                                          1
# [ECHA Name : 2,4-di-tert-butyl-6-(5-chlorobenzotriazol-2-yl)phenol, CHA Name : Tris(nonylphenyl) phosphite, CHA Name : C,C'-azodi(formamide)]                                                                                                                                                                            1
# [ECHA Name : "silicon dioxide; synthetic amorphous silicon dioxide (nano)", CHA Name : Nickel]                                                                                                                                                                                                                           1
# [ECHA Name : 2-(2H-benzotriazol-2-yl)-4,6-ditertpentylphenol, CHA Name : Lead, CHA Name : Bis(2-ethylhexyl) phthalate]                                                                                                                                                                                                   1
# [ECHA Name : Decamethylcyclopentasiloxane]                                                                                                                                                                                                                                                                               1
# [ECHA Name : Imidazolidine-2-thione]                                                                                                                                                                                                                                                                                     1
# [ECHA Name : Lead monoxide]                                                                                                                                                                                                                                                                                              1
# Name: Declarables, dtype: int64

# %%
le = LabelEncoder()
le.fit(df['Policy'])
test = le.transform(df['Policy'])
test
df['Policy'] = test

# %%
df.tail()
# Out:
#                                                Description  Policy  \
# PrimaryID
# 112996                                   14GA LGRN TXL (S)       5
# 112995                                    14GA GRY TXL (S)       5
# 109961                                    16GA YEL TXL (S)       5
# 108652                                    18GA GRY TXL (S)       5
# 124901                      93-144820-16S   16 WAY MS PLUG       5
# ...                                                    ...     ...
# 109965                                    16GA GRY TXL (S)       5
# 105578     YR41019   16GA/2 COND CABLE (BLK, RED) SHIELDED      11
# 105184                                  16GA   RED TXL (S)       5
# 113537                                        12GA BLU TXL      11
# 113001                                        14GA WHT TXL       5
#
#                 PolicyVersion                   Judgement         Declarables  \
# PrimaryID
# 112996       EUROHS-1907 (10)             under-threshold                 NaN
# 112995       EUROHS-1907 (10)             under-threshold                 NaN
# 109961       EUROHS-1907 (10)             under-threshold                 NaN
# 108652       EUROHS-1907 (10)             under-threshold                 NaN
# 124901       EUROHS-1907 (10)  above-threshold-exemptions  [ECHA Name : Lead]
# ...                       ...                         ...                 ...
# 109965       EUROHS-1907 (10)             under-threshold                 NaN
# 105578     EUREACH-0119 (197)             under-threshold                 NaN
# 105184       EUROHS-1907 (10)             under-threshold                 NaN
# 113537     EUREACH-0620 (209)             under-threshold                 NaN
# 113001       EUROHS-1907 (10)             under-threshold                 NaN
#
#                        Suppliers         Manufacturers  \
# PrimaryID
# 112996     THERM-O-LINK COMPANY              TXL WIRE
# 112995     THERM-O-LINK COMPANY              TXL WIRE
# 109961     THERM-O-LINK COMPANY              TXL WIRE
# 108652     THERM-O-LINK COMPANY              TXL WIRE
# 124901                 TTI INC.         AMPHENOL CORP
# ...                          ...                   ...
# 109965     THERM-O-LINK COMPANY              TXL WIRE
# 105578                IEWC CORP   ALLIED WIRE & CABLE
# 105184     THERM-O-LINK COMPANY              TXL WIRE
# 113537                IEWC CORP   TXL WIRE ,SOUTHWIRE
# 113001     THERM-O-LINK COMPANY              TXL WIRE
#
#                                      OtherIDs
# PrimaryID
# 112996                14GA_x000D_,14GA_x000D_
# 112995                14GA_x000D_,14GA_x000D_
# 109961                16GA_x000D_,16GA_x000D_
# 108652                18GA_x000D_,18GA_x000D_
# 124901            93-144820-16S,93-144820-16S
# ...                                       ...
# 109965                16GA_x000D_,16GA_x000D_
# 105578                        A1238-H,A1238-H
# 105184                16GA_x000D_,16GA_x000D_
# 113537     12GA_x000D_,12GA_x000D_,F120151030
# 113001                14GA_x000D_,14GA_x000D_
#
# [36077 rows x 8 columns]
